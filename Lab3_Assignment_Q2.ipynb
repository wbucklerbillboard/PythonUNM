# %% [markdown]
# # Lab3 Python for Data Science 2
# ----------------------------------

# %% [markdown]
# # HOMEWORK ASSIGNMENT

# %% [markdown]
# **Answer the following questions in the jupyter notebook file. (You can also use other IDEs to test your code) **

# %% [markdown]
# ## 1. Explore Plotting in Python. (20 points)

# %% [markdown]
# Read lecture slides "Plotting in Python". Check the links to explore the galleries and examples of different visualization libraries to learn what's possible to do in Python.
#
# Write down 5 different plots that you can use in your research, and explain how you can use them.

# %%
#1 histogram_demo_multihist.py (https://matplotlib.org/examples/statistics/histogram_demo_multihist.html)

Under the Stacked Bar (upper right) I'd want to know which combination of resources contribute to a certain type of productivity within a city.

# %%
#2 streamplot_demo_features (https://matplotlib.org/examples/images_contours_and_fields/streamplot_demo_features.html)

I'd want to know the migration, and where that flow converges, within a city.

# %%
#3 contour_demo.py (https://matplotlib.org/examples/pylab_examples/contour_demo.html)

I'd want to know the generalized height of the buildings, to help denote where executive and suburban districts are, 
so as to infer quality of life, and economics

# %%
#4 fill_demo.py  (https://matplotlib.org/examples/lines_bars_and_markers/fill_demo.html)

I'd want to know districts according to building height.  All the values within the line denote buildings of a certain height 
within a certain district, while those buildings of a differnt height are beyond it.  Which makes the line containing a fill as a boundary
for the district.

# %%
#5  scatter_with_legend.py  (https://matplotlib.org/examples/lines_bars_and_markers/scatter_with_legend.html)

With the x and y axis representing geographic coordinates, the colored circles could represent 
the intensity of resources used at certain coordinates.

# %% [markdown]
# ## 2. Finish the tutorial (30 points)

# %% [markdown]
# Read the __tutorial "Visualization"__ at http://pandas.pydata.org/pandas-docs/stable/visualization.html#visualization.
# Practice the examples in your python IDE.
#
# After that, use the knowledge you learnt in the tutorial to __create 2 different plots__.
# 1. You can choose any data to create the plots.
# 2. Use different types of plots, e.g. line plot, bar plot,scatter plot, etc. (http://pandas.pydata.org/pandas-docs/stable/visualization.html#basic-plotting-plot and http://pandas.pydata.org/pandas-docs/stable/visualization.html#other-plots)
# 2. Do not only use the default format of .plot(). Format the plot using knowledge from http://pandas.pydata.org/pandas-docs/stable/visualization.html#plot-formatting and https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html#.
# 3. Explain what type of plots and what types of formatting you used in the comments.
#
# e.g.

# %%
#This is an example
#import pandas, matplotlib, np
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline to show plot in JupyterNotebook
# %matplotlib inline
# generate a random dataframe as testing data
df = pd.DataFrame(np.random.randn(100, 4), columns=list('ABCD'))
df = df.cumsum()
# plot dataframe df using style: 
# green dash-dot line
# turn off legend
# give a title: "Task 3 Figure"
df.plot(style = "g-.",legend=False, title = "Task 3 Figure")

# %%
# 1st plot

# %%
# 2nd plot

# %% [markdown]
# ## 3. Simple scatter plot using random (20 points)

# %% [markdown]
# The aim of this task is to create a simple scatter plot using random numbers and save an image of that plot into your personal folder for this exercise.
#
# The end result should look something like this:

# %%
# For display, no code needed in this cell.

# %% [markdown]
# Steps:
#
# import pandas, matplotlib, np
#
# %matplotlib inline to show plot in JupyterNotebook

# %% [markdown]
# create a dataframe of 1000 random points using numpy's np.random.rand() -function that is useful for creating these kind of test plots.
# The dataframe will have two columns for the x and y cordinates of the points.

# %%
# generate a random dataframe as testing data
df =

# %% [markdown]
# create a 1000x3 numpy array representing 1000 random colors (which is basically an array full of random numbers, each row is a rgb value for a color) so that we get a little bit of sweeter looking plot as a result.
# (Hint: np.random.rand())

# %%
color =

# %% [markdown]
# create a scatter plot of points (point-size=50) with random colors using Dataframe.plot.scatter() -function. (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.scatter.html)
#
# 1. You can modify the size of a point using parameter s
# 2. You can set the colors for the points using parameter c
# 3. add a title and x and y -labels to your plot as shown in the figure above.

# %% [markdown]
# ## 4. Online Retails Purchase (30 points)

# %% [markdown]
# ### Introduction:
#
#
#
# ### Step 1. Import the necessary libraries

# %%
#Import the necessary libraries

# set the graphs to show in the jupyter notebook

# %% [markdown]
# ### Step 2. Read the dataset from this Online_Retail.csv.

# %% [markdown]
# ### Step 3. Assign it to a variable called online_rt

# %%
url = 'Online_Retail.csv'
online_rt = pd.read_csv(url, encoding = "ISO-8859-1")
online_rt.head()

# %% [markdown]
# ### Step 4. Find 10 countries that have the most 'Quantity' ordered except UK

# %%
# group by the Country (Hint. groupby() function,.groupby('Country').sum())

# sort the value and get the first 10 after UK, using .sort_values()

# get the first 10 after UK (2nd - 11th in quantities)

# %% [markdown]
# ### Step 5. Create a bar plot with the 10 countries that have the most 'Quantity' ordered except UK

# %%
# create the plot, set the tile

# %% [markdown]
# ## **Deliverable: Upload your finished notebook file (renamed it to "LastName_Lab3.ipynb") on UNM Learn in the Assignments section.**
